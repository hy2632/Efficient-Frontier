# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
from main import EfficientFrontier

# %%
instance = EfficientFrontier(
    symbols=["AAPL", "XOM", "PFE", "F", "WMT", "BA", "TSLA", "AMD"],
    start_date="20200101",
    end_date="20210201", 
    simulation_times=5000, 
    solve_granularity=500, 
    analytical_solution=True,
    use_optimizer=True,
    tangency_line=True,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#
# ===Fetching assets data===
# 100%|██████████| 8/8 [00:09<00:00,  1.23s/it]
# 100%|██████████| 5000/5000 [00:00<00:00, 51546.71it/s]
# 100%|██████████| 500/500 [00:00<00:00, 31254.59it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]Successfully fetched assets data!
#
# ===Running 5000 Monte Carlo simulations===
# Success!
#
# ===Deriving Analytical solution of efficient frontier===
# Success!
#
# ===Get efficient frontier using optimizer===
# 100%|██████████| 500/500 [00:03<00:00, 148.23it/s]Success!
#
# ===Plot the tangency line (efficient frontier with risk-free asset)===
# Success! Optimal sharpe ratio: 0.20598788821464176

# %%
instance.plot((12,8))
