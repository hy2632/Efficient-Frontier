# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
from main import EfficientFrontier

# %%
instance = EfficientFrontier(
    symbols=["AAPL", "XOM", "PFE", "F", "WMT", "BA", "TSLA", "AMD"],
    start_date="20200101",
    end_date="20210130", 
    simulation_times=5000, 
    solve_granularity=1000, 
    analytical_solution=True,
    use_optimizer=True,
    tangency_line=True,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#
# ===Fetching assets data===
# 100%|██████████| 8/8 [00:09<00:00,  1.18s/it]
# 100%|██████████| 5000/5000 [00:00<00:00, 58142.30it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28570.77it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]Successfully fetched assets data!
#
# ===Running 5000 Monte Carlo simulations===
# Success!
#
# ===Deriving Analytical solution of efficient frontier===
# Success!
#
# ===Get efficient frontier using optimizer===
# 100%|██████████| 1000/1000 [00:05<00:00, 180.18it/s]Success!
#
# ===Plot the tangency line (efficient frontier with risk-free asset)===
# Success! Optimal sharpe ratio: 0.23716711394540044

# %%
instance.plot((12,8))
