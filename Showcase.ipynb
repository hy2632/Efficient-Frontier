# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
from main import EfficientFrontier

# %%
instance = EfficientFrontier(
    symbols=["AAPL", "XOM", "PFE", "F", "WMT", "BA", "TSLA", "AMD"],
    start_date="20201101",
    end_date="20210201", 
    simulation_times=5000, 
    solve_granularity=500, 
    analytical_solution=True,
    use_optimizer=True,
    tangency_line=True,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#
# ===Fetching assets data===
# 100%|██████████| 8/8 [00:31<00:00,  3.93s/it]
#  27%|██▋       | 1363/5000 [00:00<00:00, 13604.81it/s]Successfully fetched assets data!
#
# ===Running 5000 Monte Carlo simulations===
# 100%|██████████| 5000/5000 [00:00<00:00, 17350.05it/s]
# 100%|██████████| 500/500 [00:00<00:00, 35639.79it/s]
#   8%|▊         | 40/500 [00:00<00:01, 393.07it/s]Success!
#
# ===Deriving Analytical solution of efficient frontier===
# Success!
#
# ===Get efficient frontier using optimizer===
# 100%|██████████| 500/500 [00:06<00:00, 78.25it/s]Success!
#
# ===Plot the tangency line (efficient frontier with risk-free asset)===
# Success! Optimal sharpe ratio: 0.4160558738962644

# %%
instance.plot((12,8))
